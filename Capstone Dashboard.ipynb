# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash  

# !pip install --upgrade plotly 

# !pip install pandas dash
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\julie\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: plotly in c:\users\julie\anaconda3\lib\site-packages (from dash==1.19.0) (5.4.0)
# Requirement already satisfied: click>=5.1 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\julie\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: brotli in c:\users\julie\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\julie\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: six in c:\users\julie\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: jupyter_dash in c:\users\julie\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: retrying in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipython in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: ipykernel in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: ansi2html in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: dash in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in c:\users\julie\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: plotly in c:\users\julie\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.4.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\julie\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\julie\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\julie\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\julie\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\julie\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\julie\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tornado>=4.2 in c:\users\julie\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\julie\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\julie\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: decorator in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: colorama in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: pygments in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: pickleshare in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: backcall in c:\users\julie\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\julie\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\julie\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\julie\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\julie\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\julie\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\julie\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\julie\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\julie\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\julie\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\julie\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\julie\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julie\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\julie\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: plotly in c:\users\julie\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\julie\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\julie\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: pandas in c:\users\julie\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: dash in c:\users\julie\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\julie\anaconda3\lib\site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in c:\users\julie\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\julie\anaconda3\lib\site-packages (from dash) (5.4.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\julie\anaconda3\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\julie\anaconda3\lib\site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\julie\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\julie\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\julie\anaconda3\lib\site-packages (from dash) (1.10.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\julie\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\julie\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\julie\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\julie\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\julie\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\julie\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: brotli in c:\users\julie\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\julie\anaconda3\lib\site-packages (from plotly->dash) (8.0.1)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
spacex = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')
spacex.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site Mission Outcome  class  \
# 0           0              1  CCAFS LC-40         Success      0
# 1           1              2  CCAFS LC-40         Success      0
# 2           2              3  CCAFS LC-40         Success      0
# 3           3              4  CCAFS LC-40         Success      0
# 4           4              5  CCAFS LC-40         Success      0
#
#    Payload Mass (kg) Booster Version Booster Version Category
# 0                0.0  F9 v1.0  B0003                     v1.0
# 1                0.0  F9 v1.0  B0004                     v1.0
# 2              525.0  F9 v1.0  B0005                     v1.0
# 3              500.0  F9 v1.0  B0006                     v1.0
# 4              677.0  F9 v1.0  B0007                     v1.0

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                            options=[
                                                {'label': 'All Sites', 'value': 'ALL'},
                                                {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                                {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                            ],
                                            value='ALL',
                                            placeholder="Select a Launch Site",
                                            searchable=True
                                            ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                    
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0',
                                                       2500: '2500',
                                                       5000: '5000',
                                                       7500: '7500'},
                                                value=[min_payload, max_payload]),
                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    if entered_site == 'ALL':
        df = spacex_df
        fig = px.pie(df, values='class', 
        names='Launch Site', 
        title='Total Successes by Launch Site')
        return fig
    else:
        df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = df.groupby('class').size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count',
        names='class',
        title='Total Success Launches By %s' % entered_site)
        return fig
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'),
               Input(component_id="payload-slider", component_property="value")])
def get_scatter_plot(entered_site, slider_range):
    low, high = slider_range
    if entered_site == 'ALL':
        df = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(df[mask], x="Payload Mass (kg)", y="class", 
                         color="Booster Version Category",
                         title='Correlation between Payload and Success for all Sites')
        return fig
    else:
        df = spacex_df[spacex_df['Launch Site'] == entered_site]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(df[mask], x="Payload Mass (kg)", y="class", 
                         color="Booster Version Category",
                         title='Correlation between Payload and Success for %s' % entered_site)
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash app running on http://127.0.0.1:8050/
